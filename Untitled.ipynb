# %%
import numpy as np
from utils.plot import *

# %%
episodes = np.loadtxt('episodes')
mp = np.loadtxt('episodes')
mppe = np.loadtxt('episodes')

# %%
def episode_durations_uncer(ep):
    mean = ep.mean(axis=0)
    smoothed = smooth(mean, 30)
    std = ep.std(axis=0)[:smoothed.shape[0]]
    plt.plot(smoothed)
    plt.fill_between(np.arange(smoothed.shape[0]), smoothed - std, smoothed + std, alpha=0.3)
    plt.title('Episode durations per episode')
    plt.savefig('episode_duration_uncer')
    plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d3f938b79ccf> in <module>()
# ----> 1 smoothed.shape
#
# NameError: name 'smoothed' is not defined

# %%
episode_durations_uncer(episodes)
# Out:
# (2971,)
# (2971,)
